# %% [markdown]
# 1. Show ground truth in coco
# 2. Show ground truth in general
# 2. Show ground truth in general with instance segmentation prediction
# 3. Show ground truth in general with semantic segmantation prediction

# %%
ROOT = "/home/james/Desktop/mygithub/COSMOs"

import os
os.chdir(ROOT)

from cosmos.segmentation import show_coco, show_general

# %% [markdown]
# 1. Show ground truth in coco

# %%
help(show_coco)
# Out:
# Help on function show_coco in module cosmos.segmentation.visualization:
#
# show_coco(img_name: str, img_folder: str, ant_path: str, save_folder: str = '.tmp', use_cache: bool = True)
#     Show an image with its ground truth in coco format.
#     This func will convert coco format data into `general` format.
#     Args:
#         img_name (str): name of target image to be shown
#         img_folder (str): path to the image folder
#         ant_path (str): path to the coco label
#         save_folder (Optional[str], optional): folder saves the conversion result and visualized output
#         use_cache (bool, optional): if true, the conversion execute once only.

# %%
show_coco(
    "img1.jpg",
    f"{ROOT}/example/segmentation/data/coco",
    f"{ROOT}/example/segmentation/data/coco/coco.json"
)

# %% [markdown]
# 2. Show ground truth in general

# %%
help(show_general)
# Out:
# Help on function show_general in module cosmos.segmentation.visualization:
#
# show_general(img_name: str, ant_path: str, save_path: Optional[str] = None)
#     Args:
#         img_name (str): image name
#         ant_path (str): path to general.json
#         save_path (str): save path. if None, not saved.

# %%
show_general(
    "img1.jpg",
    f"{ROOT}/example/segmentation/data/general/general.json"
)

# %% [markdown]
# 3. Show ground truth in general with instance segmentation prediction

# %%
show_general(
    "img1.jpg",
    f"{ROOT}/example/segmentation/prediction/instance/general.json",
)

# %% [markdown]
# 4. Show ground truth in general with semantic segmantation prediction

# %%
show_general(
    "img1.jpg",
    f"{ROOT}/example/segmentation/prediction/semantic/general.json",
)
