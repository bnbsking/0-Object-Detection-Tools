# %% [markdown]
# # Visualization of ground truth and prediction
#
# + ground truth only
#     + 1 show_coco
#     + 2 show_voc
#     + 3 show_yolo
#
# <br>
#
# + ground truth and prediction
#     + 4 show_general (please convert raw format to general first)
#         + e.g. `coco2general` / `voc2general` / `yolo2general`
#     + 5 show (low level function)

# %%
ROOT = "/home/james/Desktop/mygithub/COSMOduleS"

import glob
import os
os.chdir(ROOT)

from cosmodules.detection import show_coco, show_voc, show_yolo, show_general, show

# %% [markdown]
# ### 1. show_coco

# %%
help(show_coco)
# Out:
# Help on function show_coco in module cosmodules.detection.visualization:
#
# show_coco(img_name: str, img_folder: str, ant_path: str, save_folder: str = '.tmp', use_cache: bool = True)
#     Show an image with its ground truth in coco format.
#     This func will convert coco format data into `general` format.
#     Args:
#         img_name (str): name of target image to be shown
#         img_folder (str): path to the image folder
#         ant_path (str): path to the coco label
#         save_folder (Optional[str], optional): folder saves the conversion result and visualized output
#         use_cache (bool, optional): if true, the conversion execute once only.

# %%
for i in range(3):
    show_coco(
        img_name = f"pic{i}.jpg",
        img_folder = "example/detection/data/coco",
        ant_path = "example/detection/data/coco/coco.json",
        use_cache = False
    )

# %% [markdown]
# ### 2. show_voc

# %%
help(show_voc)
# Out:
# Help on function show_voc in module cosmodules.detection.visualization:
#
# show_voc(img_name: str, img_path_list: List[str], ant_path_list: List[str], class_list: List[str], save_folder: str = '.tmp', use_cache: bool = True)
#     Show an image with its ground truth in voc format.
#     This func will convert voc format data into `general` format.
#     Args:
#         img_name (str): name of target image to be shown
#         img_path_list (List[str]): list of image path of the dataset
#         ant_path_list (List[str]): list of annotation path of the dataset
#         class_list (List[str]): list of class name
#         save_folder (Optional[str], optional): folder saves the conversion result and visualized output
#         use_cache (bool, optional): if true, the conversion execute once only.

# %%
for i in range(3):
    show_voc(
        img_name = f"pic{i}.jpg",
        img_path_list = sorted(glob.glob("example/detection/data/voc/*.jpg")),
        ant_path_list = sorted(glob.glob("example/detection/data/voc/*.xml")),
        class_list = ["dog", "cat"],
        use_cache = False
    )
# Out:
# 3it [00:00, 927.67it/s]
# 3it [00:00, 7677.19it/s]
# 3it [00:00, 3554.49it/s]

# %% [markdown]
# ### 3. show_yolo

# %%
help(show_yolo)
# Out:
# Help on function show_yolo in module cosmodules.detection.visualization:
#
# show_yolo(img_name: str, img_path_list: List[str], ant_path_list: List[str], class_list: List[str], save_folder: str = '.tmp', use_cache: bool = True)
#     Show an image with its ground truth in yolo format.
#     This func will convert yolo format data into `general` format.
#     Args:
#         img_name (str): name of target image to be shown
#         img_path_list (List[str]): list of image path of the dataset
#         ant_path_list (List[str]): list of annotation path of the dataset
#         class_list (List[str]): list of class name
#         save_folder (Optional[str], optional): folder saves the conversion result and visualized output
#         use_cache (bool, optional): if true, the conversion execute once only.

# %%
for i in range(3):
    show_yolo(
        img_name = f"pic{i}.jpg",
        img_path_list = sorted(glob.glob("example/detection/data/yolo/*.jpg")),
        ant_path_list = sorted(path for path in glob.glob("example/detection/data/yolo/*.txt") if "classes.txt" not in path),
        class_list = ["dog", "cat"],
        use_cache = False
    )
# Out:
# 3it [00:00, 108.88it/s]
# 3it [00:00, 206.88it/s]
# 3it [00:00, 128.36it/s]

# %% [markdown]
# ### 4. show_general

# %%
help(show_general)
# Out:
# Help on function show_general in module cosmodules.detection.visualization:
#
# show_general(img_name: str, ant_path: str, save_path: Optional[str] = None)
#     Show an image with its ground truth (and prediction if it exists) in general format.
#     Hint: Convert coco / voc / yolo to general first by `coco2general` / `voc2general` / `yolo2general`
#     Args:
#         img_name (str): name of target image to be shown
#         ant_path (str): path to the general format
#         save_path (Optional[str]): path to save the visualized result

# %%
for i in range(3):
    show_general(
        img_name = f"pic{i}.jpg",
        ant_path = "example/detection/data/general.json",
    )

# %% [markdown]
# ### 5. show

# %%
data_dict = {
    "img_path": f"{ROOT}/example/detection/data/coco/pic0.jpg",
    "img_width": 221,
    "img_height": 228,
    "gt_boxes": [
        [
            0,
            23,
            220,
            228
        ]
    ],
    "gt_cls": [
        1
    ],
    "pd_boxes": [
        [
            0,
            23,
            220,
            228
        ],
        [
            30,
            90,
            80,
            150
        ]
    ],
    "pd_probs": [
        [
            0.0,
            0.95,
            0.05
        ],
        [
            0.0,
            0.2,
            0.8
        ]
    ],
}

show(
    class_list = ["dog", "cat"],
    data_dict = data_dict,
)
