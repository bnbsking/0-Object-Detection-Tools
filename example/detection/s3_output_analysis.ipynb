# %%
ROOT = "/Users/james.chao/Desktop/codeMore/mygithub/Object-Detection-Tools"

import os
os.chdir(ROOT)

from cosmos.detection import DetectionAnalysis

# %%
obj = DetectionAnalysis(
    ant_path = f"{ROOT}/example/detection/data/gt_and_pd.json",
    save_folder = f"{ROOT}/example/detection/output/metrics"
)
# Out:
# 101it [00:00, 1396.59it/s]

# %%
print(os.listdir(f"{ROOT}/example/detection/output/metrics"))
# Out:
# ['metrics.json', 'worst_acc', 'prf_curves.jpg', 'all_wrong', 'aps.jpg', 'confusion.jpg', 'pr_curves.jpg']
