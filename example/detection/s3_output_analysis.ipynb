# %%
ROOT = "/home/james/Desktop/mygithub/COSMOs"

import os
os.chdir(ROOT)

from cosmos.detection import DetectionAnalysis

# %%
obj = DetectionAnalysis(
    ant_path = f"{ROOT}/example/detection/prediction/general.json",
    save_folder = f"{ROOT}/example/detection/output/metrics"
)
# Out:
# 101it [00:00, 1777.58it/s]

# %%
print(os.listdir(f"{ROOT}/example/detection/output/metrics"))
# Out:
# ['metrics.json', 'aps.jpg', 'all_wrong', 'worst_acc', 'pr_curves.jpg', 'confusion.jpg', 'prf_curves.jpg']
