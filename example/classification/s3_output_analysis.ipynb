# %% [markdown]
# 1. Single Label (binary, multi-class)
# 2. Multi Label (multi-label)
# 3. Single Label Background (binary, multi-class)

# %%
ROOT = "/home/james/Desktop/mygithub/COSMOduleS"

import os
os.chdir(ROOT)

from cosmodules.classification import ClassificationAnalysis

# %% [markdown]
# 1. Single Label (binary, multi-class)

# %%
ClassificationAnalysis(
    ant_path = f"{ROOT}/example/classification/prediction/single_label.json",
    save_folder = f"{ROOT}/example/classification/output/metrics/single_label",
)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ClassificationAnalysis(
#       2     ant_path = f"{ROOT}/example/classification/prediction/single_label.json",
#       3     save_folder = f"{ROOT}/example/classification/output/metrics/single_label",
#       4 )
#
# File ~/Desktop/mygithub/COSMOduleS/cosmodules/classification/output_analysis.py:17, in ClassificationAnalysis.__init__(self, ant_path, save_folder, pipeline_cfg_path)
#      11 def __init__(
#      12         self,
#      13         ant_path: str,
#      14         save_folder: str,
#      15         pipeline_cfg_path: Optional[str] = None
#      16     ):
# ---> 17     super().__init__(ant_path, save_folder, pipeline_cfg_path)
#
# File ~/Desktop/mygithub/COSMOduleS/cosmodules/utils/analysis/base_analysis.py:39, in BaseAnalysis.__init__(self, ant_path, save_folder, pipeline_cfg_path)
#      30 metrics_pipeline_cls = getattr(pipelines, pipeline_cfg["metrics_pipeline"]["name"])
#      31 metrics_pipeline = metrics_pipeline_cls(
#      32     num_classes = num_classes,
#      33     labels = labels,
#    (...)
#      37     start_idx = start_idx
#      38 )
# ---> 39 metrics = metrics_pipeline.run()
#      41 # plotting pipeline
#      42 plotting_pipeline_cls = getattr(pipelines, pipeline_cfg["plotting_pipeline"]["name"])
#
# File ~/Desktop/mygithub/COSMOduleS/cosmodules/utils/pipelines/metrics_pipelines.py:45, in BaseMetricsPipeline.run(self)
#      42 def run(self) -> Dict:
#      43     for func_dict in self.func_dicts:
#      44         self.metrics[func_dict["log_name"]] = \
# ---> 45             getattr(self, func_dict["func_name"])(**func_dict["func_args"])
#      46     os.makedirs(os.path.dirname(self.save_path), exist_ok=True)
#      47     with open(self.save_path, "w") as f:
#
# File ~/Desktop/mygithub/COSMOduleS/cosmodules/utils/pipelines/metrics_pipelines.py:201, in CommonMetricsPipeline.get_confusion_axis_norm(self, confusion_key, axis)
#     199 for i in range(len(confusion_axis_norm)):
#     200     if axis == 0:
# --> 201         confusion_axis_norm[:, i] /= (axis_sum[i] + 1e-10)
#     202     elif axis == 1:
#     203         confusion_axis_norm[i, :] /= (axis_sum[i] + 1e-10)
#
# UFuncTypeError: Cannot cast ufunc 'divide' output from dtype('float64') to dtype('int64') with casting rule 'same_kind'

# %% [markdown]
# 2. Multi Label (multi-label)

# %%
ClassificationAnalysis(
    ant_path = f"{ROOT}/example/classification/prediction/multi_label.json",
    save_folder = f"{ROOT}/example/classification/output/metrics/multi_label"
)

# %% [markdown]
# 3. Single Label Background (binary, multi-class)

# %%
ClassificationAnalysis(
    ant_path = f"{ROOT}/example/classification/prediction/single_label_background.json",
    save_folder = f"{ROOT}/example/classification/output/metrics/single_label_background",
)
